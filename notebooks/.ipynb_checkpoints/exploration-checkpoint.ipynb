# %%
import pandas as pd

# %%
df = pd.read_csv("../data/logins_raw.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0  hour_of_day country device_type  login_success  \
# 0           0           11      US      mobile           True
# 1           1           22      UK      mobile           True
# 2           2           18      FR      mobile           True
# 3           3           16      US     desktop           True
# 4           4            8      FR      mobile           True
# 5           5            8      US     desktop           True
# 6           6            4      DE      mobile           True
# 7           7           20      DE     desktop           True
# 8           8           16      US     desktop           True
# 9           9           18      UK     desktop           True
#
#    sessions_per_hour
# 0                  2
# 1                  4
# 2                  3
# 3                  5
# 4                  5
# 5                  7
# 6                  3
# 7                  6
# 8                  5
# 9                  4

# %%
print(f"\nDataset shape: {df.shape}")
# Out:
# Dataset shape: (5003, 6)

# %%
print(f"\nValue counts:\n{df['country'].value_counts()}")
# Out:
# Value counts:
# country
# US    2025
# UK    1084
# CA     715
# FR     500
# DE     458
# AU     218
# RU       1
# CN       1
# BR       1
# Name: count, dtype: int64
